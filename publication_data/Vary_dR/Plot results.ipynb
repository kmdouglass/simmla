# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xdata1 = np.load('./x-coords4_dR_-500.npy')
ydata1 = np.load('./avgIrrad4_dR_-500.npy')

xdata2 = np.load('./x-coords4_dR_-1000.npy')
ydata2 = np.load('./avgIrrad4_dR_-1000.npy')

xdata3 = np.load('./x-coords4_dR_-5000.npy')
ydata3 = np.load('./avgIrrad4_dR_-5000.npy')

# %%
plt.plot(xdata1, ydata1)
plt.plot(xdata2, ydata2)
plt.plot(xdata3, ydata3)
plt.xlim((-150, 150))
plt.grid(True)
plt.show()

# %%
from scipy.integrate import simps

# %%
power = simps(ydata3, xdata3)

# %%
power
# Out:
# 97.965038010746916551
